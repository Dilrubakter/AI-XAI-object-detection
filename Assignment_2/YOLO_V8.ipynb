# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="YFtwixKqmtAUazxzomLI")
project = rf.workspace("cse475").project("eye-diseases-1edmw")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.50-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.8.30)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.53.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.3.2)
# Downloading roboflow-1.1.50-py3-none-any.whl (81 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 4.1 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.0 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 4.4 MB/s eta 0:00:00
# Installing collected packages: filetype, python-dotenv, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.50
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in eye-diseases-1 to yolov8:: 100%|██████████| 79873/79873 [00:01<00:00, 77678.67it/s]
# Extracting Dataset Version Zip to eye-diseases-1 in yolov8:: 100%|██████████| 4812/4812 [00:00<00:00, 8951.96it/s]

# %%
# %pip install ultralytics supervision roboflow
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (4 CPUs, 31.4 GB RAM, 6037.7/8062.4 GB disk)

# %%
pip install ultralytics --upgrade
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.3.53)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.1)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.4.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.19.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.13)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.6.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !sed -i '$d' {dataset.location}/data.yaml   # Delete the last line
# !sed -i '$d' {dataset.location}/data.yaml   # Delete the second-to-last line
# !sed -i '$d' {dataset.location}/data.yaml   # Delete the third-to-last line

# !echo 'test: ../test/images' >> {dataset.location}/data.yaml
# !echo 'train: ../train/images' >> {dataset.location}/data.yaml
# !echo 'val: ../valid/images' >> {dataset.location}/data.yaml

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/kaggle/working/eye-diseases-1/data.yaml epochs=100 imgsz=640 batch=32 lr0=0.005 momentum=0.95 weight_decay=0.001 cos_lr=True plots=True
# Out:
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolov8s.pt to 'yolov8s.pt'...
# 100%|███████████████████████████████████████| 21.5M/21.5M [00:00<00:00, 147MB/s]
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/kaggle/working/eye-diseases-1/data.yaml, epochs=100, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=True, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.005, lrf=0.01, momentum=0.95, weight_decay=0.001, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 17.4MB/s]
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2119918  ultralytics.nn.modules.head.Detect           [10, [128, 256, 512]]
# Model summary: 225 layers, 11,139,470 parameters, 11,139,454 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.3.0/yolo11n.pt to 'yolo11n.pt'...
# 100%|██████████████████████████████████████| 5.35M/5.35M [00:00<00:00, 70.1MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/working/eye-diseases-1/train/labels... 2100 images, 162
# train: New cache created: /kaggle/working/eye-diseases-1/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.23 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/eye-diseases-1/valid/labels... 162 images, 9 backg
# val: New cache created: /kaggle/working/eye-diseases-1/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.005' and 'momentum=0.95' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.001), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       1/100      7.67G      2.111      5.267      2.203         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.166      0.356      0.239       0.11
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       2/100      7.28G      1.853      2.899      1.968         52        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.163      0.357      0.197     0.0749
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       3/100      7.29G      1.869      2.621      2.017         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.409      0.296      0.198     0.0987
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       4/100      7.37G      1.871      2.541      2.031         62        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.433      0.299      0.269      0.103
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       5/100       7.6G      1.848      2.431      2.016         55        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.507      0.339      0.326      0.131
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       6/100      7.33G      1.802      2.359       1.98         55        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.323      0.466      0.411       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       7/100      7.65G      1.766      2.274      1.944         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.596      0.453      0.425      0.185
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       8/100      7.29G       1.73      2.204      1.935         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.556      0.468      0.452      0.215
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       9/100      7.66G       1.73      2.181      1.908         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.578       0.45      0.462      0.211
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      10/100      7.61G       1.71      2.106      1.906         53        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.498      0.506      0.481      0.218
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      11/100      7.66G      1.679      2.076      1.873         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.756      0.468      0.547      0.275
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      12/100      7.35G      1.663      2.043      1.853         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.466      0.437      0.418      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      13/100      7.31G      1.644      1.985      1.851         46        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.625       0.51      0.555      0.271
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      14/100      7.65G      1.593      1.936      1.806         55        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.538      0.526      0.505      0.248
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      15/100      7.63G      1.637      1.911       1.84         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.545      0.542      0.544      0.279
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      16/100      7.61G      1.606      1.932      1.816         53        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.617      0.546      0.551      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      17/100      7.61G      1.603      1.857      1.812         52        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.453      0.622      0.554      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      18/100      7.61G      1.587      1.812      1.793         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.574      0.521      0.538      0.268
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      19/100      7.64G      1.567      1.784      1.787         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.47      0.575       0.52      0.267
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      20/100      7.33G      1.571      1.786      1.793         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.53      0.511      0.547      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      21/100       7.7G      1.564      1.765      1.783         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.629      0.516      0.559      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      22/100      7.29G      1.512      1.718      1.736         53        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.505      0.527      0.538      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      23/100      7.62G      1.525      1.706      1.742         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.668      0.529      0.554      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      24/100      7.64G      1.515      1.673      1.729         39        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.697      0.554      0.541      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      25/100      7.34G      1.492      1.653      1.725         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.51      0.653      0.586      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      26/100      7.29G      1.461      1.614      1.713         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.498      0.557      0.551      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      27/100      7.33G      1.446      1.577      1.693         43        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.55      0.649      0.578      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      28/100      7.67G      1.464       1.58      1.699         37        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.551      0.616      0.579       0.31
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      29/100      7.57G       1.46      1.552      1.703         53        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.571      0.678      0.612      0.313
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      30/100      7.66G      1.434       1.52       1.68         62        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.508      0.643      0.546      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      31/100      7.67G      1.403        1.5      1.659         49        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.609      0.603      0.606      0.329
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      32/100      7.62G      1.403      1.488      1.653         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.511      0.626      0.568        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      33/100      7.62G      1.423      1.469       1.66         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.506      0.581       0.56      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      34/100      7.62G      1.395      1.456      1.645         72        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.547       0.57      0.572      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      35/100      7.67G      1.363      1.456      1.614         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.544      0.652      0.581      0.317
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      36/100      7.64G      1.375      1.424      1.624         58        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.487      0.664      0.565      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      37/100      7.67G      1.364      1.405      1.632         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.544      0.599      0.576      0.307
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      38/100      7.62G      1.357      1.393      1.603         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.552       0.61      0.578      0.312
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      39/100      7.31G      1.337      1.378      1.608         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.546      0.643      0.579      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      40/100      7.31G      1.316      1.349      1.585         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.492      0.679      0.566        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      41/100      7.62G      1.299      1.303      1.563         51        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.489      0.707      0.552      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      42/100      7.66G      1.323      1.349      1.589         61        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.556      0.664      0.579      0.305
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      43/100      7.62G      1.306      1.334      1.568         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.506      0.616      0.557      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      44/100      7.32G      1.271      1.319      1.551         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.526       0.67      0.568      0.306
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      45/100      7.66G      1.256      1.284      1.548         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.557      0.646       0.57      0.303
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      46/100      7.64G      1.277      1.292      1.563         35        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.513      0.638      0.561      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      47/100      7.64G      1.257      1.246      1.539         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.493      0.674      0.553      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      48/100      7.32G      1.236      1.228      1.525         44        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.533      0.706      0.588      0.308
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      49/100      7.61G      1.236      1.241       1.52         30        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.571      0.608      0.577      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      50/100      7.63G      1.197      1.229      1.499         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.54      0.655      0.576        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      51/100      7.64G      1.179      1.186      1.482         52        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.534      0.646      0.572      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      52/100      7.29G      1.203      1.192      1.504         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.557      0.643      0.576      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      53/100      7.61G      1.185      1.169      1.486         47        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.525      0.667      0.553      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      54/100      7.29G      1.193      1.192      1.503         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.539      0.666      0.566      0.296
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      55/100       7.6G      1.172      1.171      1.482         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.506      0.676      0.565      0.301
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      56/100      7.64G      1.162       1.16      1.477         58        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.563      0.635      0.572      0.302
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      57/100      7.64G      1.139      1.149      1.453         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.513      0.691      0.569      0.294
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      58/100      7.61G       1.15      1.139      1.461         65        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.502       0.66      0.556      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      59/100      7.63G      1.131      1.128      1.445         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.526       0.67      0.571      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      60/100      7.61G      1.126      1.109      1.443         72        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.503      0.665      0.532      0.277
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      61/100       7.3G      1.108      1.103      1.422         53        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.573      0.637      0.552      0.289
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      62/100      7.33G      1.102      1.083      1.419         50        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.516      0.666      0.556      0.298
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      63/100      7.61G      1.078       1.08      1.407         54        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.497      0.751      0.582      0.304
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      64/100      7.66G       1.08      1.079      1.409         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.512      0.654      0.555       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      7.34G       1.06      1.071      1.405         55        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.541      0.659      0.576      0.297
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      7.28G       1.06      1.053      1.382         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.493      0.707      0.564      0.291
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      7.33G      1.045      1.036      1.378         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.516      0.701      0.549      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      7.66G      1.046      1.046      1.391         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.514       0.68      0.546      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100      7.28G      1.036      1.032      1.375         41        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.511      0.696      0.552       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      7.33G      1.023      1.002      1.372         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.51      0.685      0.548       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100       7.6G      1.053       1.04      1.383         63        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.522       0.69      0.563        0.3
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      7.66G     0.9984     0.9819      1.347         64        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.538      0.672      0.571      0.293
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      7.62G     0.9997      1.007       1.35         46        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.511      0.695      0.567      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100      7.32G      1.008          1      1.344         57        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.53      0.685      0.552      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100      7.63G     0.9831     0.9763      1.335         58        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.522      0.705      0.544       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100       7.6G     0.9661     0.9796      1.329         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210        0.5      0.692      0.556      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100       7.3G     0.9826      0.987      1.338         49        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.523      0.688      0.548      0.283
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      7.33G     0.9741     0.9669       1.33         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.508      0.715      0.546      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      7.62G     0.9778     0.9589      1.319         40        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.52       0.67      0.548       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100      7.28G     0.9533     0.9552       1.32         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.526      0.671      0.542      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100       7.7G     0.9658      0.956      1.323         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.521      0.695       0.55      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      7.29G     0.9536     0.9474      1.322         49        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.542      0.679      0.553      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      7.33G     0.9485     0.9497      1.317         38        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.526      0.706      0.564      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      7.61G     0.9394     0.9306      1.302         48        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.541      0.654      0.561      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      7.63G     0.9271     0.9245      1.295         42        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.518      0.717      0.562       0.29
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100       7.3G     0.9344     0.9308      1.305         45        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.53      0.675      0.552      0.288
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      7.33G     0.9336     0.9298        1.3         56        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.522      0.705      0.548       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      7.71G     0.9338     0.9285      1.295         44        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.52      0.714      0.549      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      7.34G     0.9337     0.9168        1.3         36        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.514      0.705      0.545      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100       7.3G     0.9265     0.9212      1.292         52        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.52      0.705      0.561      0.292
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      7.62G     0.9243      0.833      1.361         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.515      0.691      0.545      0.286
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100      7.29G     0.8821     0.7999      1.335         22        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.527      0.663      0.545      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      7.29G     0.8852     0.8038      1.332         31        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.521      0.699      0.551      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      7.61G     0.8697     0.7863      1.319         32        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.524      0.684      0.551      0.285
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      7.29G     0.8653     0.7783      1.321         29        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.524      0.687      0.549      0.287
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100       7.6G     0.8591     0.7705      1.312         27        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.52      0.687      0.546      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      7.61G      0.862     0.7704      1.316         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.517      0.681      0.543      0.281
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      7.63G     0.8536     0.7836      1.311         25        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.525      0.681      0.546       0.28
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      7.61G     0.8435     0.7801      1.298         21        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210       0.52      0.671      0.542      0.282
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      7.61G     0.8528     0.7726      1.315         26        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.526      0.683      0.549      0.283
#
# 100 epochs completed in 1.027 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.613      0.607      0.611      0.329
# Central Serous Chorioretinopathy         18         18      0.954      0.944       0.96       0.47
#   Diabetic Retinopathy         13         14      0.293      0.286      0.208     0.0574
#             Disc Edema         15         15       0.96          1      0.995      0.595
#               Glaucoma         16         16      0.445        0.5      0.449       0.25
#                Healthy          9          9      0.527      0.889      0.842      0.822
#           Macular Scar         16         25      0.531       0.56      0.577       0.24
#                Mypopia         18         32      0.503      0.506      0.493        0.2
#              Pterygium         18         20      0.852        0.8      0.846      0.363
#     Retinal Detachment         14         30      0.585      0.133      0.364      0.132
#   Retinitis Pigmentosa         16         31      0.484      0.452      0.374      0.164
# Speed: 0.2ms preprocess, 5.2ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !yolo task=detect mode=train model=yolov8s.pt data=/kaggle/working/eye-diseases-1/data.yaml epochs=1 imgsz=640 batch=32 name=train_yolov8
# Out:
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/kaggle/working/eye-diseases-1/data.yaml, epochs=1, time=None, patience=100, batch=32, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train_yolov82, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train_yolov82
# Overriding model.yaml nc=80 with nc=10
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2119918  ultralytics.nn.modules.head.Detect           [10, [128, 256, 512]]
# Model summary: 225 layers, 11,139,470 parameters, 11,139,454 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train_yolov82', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /kaggle/working/eye-diseases-1/train/labels.cache... 2100 images
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.23 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/working/eye-diseases-1/valid/labels.cache... 162 images, 9
# Plotting labels to runs/detect/train_yolov82/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.000714, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train_yolov82
# Starting training for 1 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#         1/1      7.64G      2.112      5.263      2.212         60        640: 1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.173      0.368      0.264      0.125
#
# 1 epochs completed in 0.012 hours.
# Optimizer stripped from runs/detect/train_yolov82/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train_yolov82/weights/best.pt, 22.5MB
#
# Validating runs/detect/train_yolov82/weights/best.pt...
# Ultralytics 8.3.53 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 168 layers, 11,129,454 parameters, 0 gradients, 28.5 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        162        210      0.177       0.37      0.264      0.125
# Central Serous Chorioretinopathy         18         18      0.363      0.833      0.679        0.3
#   Diabetic Retinopathy         13         14      0.129     0.0714     0.0475     0.0156
#             Disc Edema         15         15      0.167          1      0.916      0.478
#               Glaucoma         16         16      0.157      0.513      0.146     0.0637
#                Healthy          9          9       0.33      0.111      0.187      0.149
#           Macular Scar         16         25       0.41       0.24       0.25     0.0969
#                Mypopia         18         32      0.108      0.594      0.191     0.0705
#              Pterygium         18         20          0          0       0.11     0.0397
#     Retinal Detachment         14         30      0.108      0.333      0.106     0.0334
#   Retinitis Pigmentosa         16         31          0          0    0.00742    0.00237
# Speed: 0.2ms preprocess, 5.6ms inference, 0.0ms loss, 7.1ms postprocess per image
# Results saved to runs/detect/train_yolov82
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
import os

# Check the contents of the 'runs/detect/train' folder
train_dir = '/kaggle/working/runs/detect/train'
os.listdir(train_dir)  # List the files in the train directory
# Out:
# ['results.csv',
#  'P_curve.png',
#  'val_batch0_pred.jpg',
#  'val_batch1_labels.jpg',
#  'weights',
#  'events.out.tfevents.1734927502.47a0e073aa31.111.0',
#  'R_curve.png',
#  'val_batch1_pred.jpg',
#  'args.yaml',
#  'results.png',
#  'F1_curve.png',
#  'val_batch0_labels.jpg',
#  'labels.jpg',
#  'train_batch1.jpg',
#  'confusion_matrix.png',
#  'train_batch0.jpg',
#  'val_batch2_labels.jpg',
#  'PR_curve.png',
#  'train_batch2.jpg',
#  'confusion_matrix_normalized.png',
#  'val_batch2_pred.jpg',
#  'labels_correlogram.jpg']

# %%
import matplotlib.pyplot as plt
import cv2

# Path to your confusion matrix image
image_path = '/kaggle/working/runs/detect/train/confusion_matrix.png'

# Load the image
img = cv2.imread(image_path)

# Check if image is loaded correctly
if img is None:
    print("Error: Image not found at", image_path)
else:
    # Convert the image from BGR to RGB (OpenCV uses BGR by default)
    img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

    # Display the image
    plt.figure(figsize=(10, 10))
    plt.imshow(img_rgb)
    plt.axis('off')  # Hide axes
    plt.show()

# %%
from IPython.display import Image


# Display the image
Image('/kaggle/working/runs/detect/train/results.png', width=600)

# %%
Image!yolo task=detect mode=train model=yolov8s.pt data=/kaggle/working/eye-diseases-1/data.yaml epochs=100 imgsz=640 batch=32 lr0=0.005 momentum=0.95 weight_decay=0.001 cos_lr=True plots=True(filename='/kaggle/working/runs/detect/train/val_batch0_pred.jpg', width=600)

# %%
import pandas as pd
from tabulate import tabulate

# Load the CSV data
# Adjust this path based on where your CSV file is located in Kaggle
results_csv_path = '/kaggle/working/runs/detect/train/results.csv'  # Adjust path if needed
results_df = pd.read_csv(results_csv_path)

# Print the columns to check for any discrepancies
print("Columns in CSV:", results_df.columns)

# Assuming column names are correct, extract the necessary metrics
accuracy_values = results_df['metrics/mAP50(B)']  # Adjusted if needed
precision_values = results_df['metrics/precision(B)']  # Adjusted if needed
recall_values = results_df['metrics/recall(B)']  # Adjusted if needed

# Calculate F1 scores
f1_scores = 2 * (precision_values * recall_values) / (precision_values + recall_values)

# Calculate average metrics
average_accuracy = accuracy_values.mean()
average_precision = precision_values.mean()
average_recall = recall_values.mean()
average_f1_score = f1_scores.mean()

# Create a dictionary with the metrics
metrics = {
    'Model': ['YOLOv8'],
    'Accuracy': [f"{average_accuracy:.2%}"],
    'Precision': [f"{average_precision:.2%}"],
    'Recall': [f"{average_recall:.2%}"],
    'F1 score': [f"{average_f1_score:.2%}"]
}

# Convert the dictionary into a DataFrame
average_metrics_df = pd.DataFrame(metrics)

# Print the result in a grid format
print(tabulate(average_metrics_df, headers='keys', tablefmt='grid'))
# Out:
# Columns in CSV: Index(['epoch', 'time', 'train/box_loss', 'train/cls_loss', 'train/dfl_loss',
#        'metrics/precision(B)', 'metrics/recall(B)', 'metrics/mAP50(B)',
#        'metrics/mAP50-95(B)', 'val/box_loss', 'val/cls_loss', 'val/dfl_loss',
#        'lr/pg0', 'lr/pg1', 'lr/pg2'],
#       dtype='object')
# +----+---------+------------+-------------+----------+------------+
# |    | Model   | Accuracy   | Precision   | Recall   | F1 score   |
# +====+=========+============+=============+==========+============+
# |  0 | YOLOv8  | 53.57%     | 52.24%      | 62.10%   | 56.23%     |
# +----+---------+------------+-------------+----------+------------+

# %%
# !git clone https://github.com/rigvedrs/YOLO-V8-CAM.git
# Out:
# Cloning into 'YOLO-V8-CAM'...
# remote: Enumerating objects: 82, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 82 (delta 9), reused 14 (delta 5), pack-reused 57 (from 1)
# Receiving objects: 100% (82/82), 29.78 MiB | 38.35 MiB/s, done.
# Resolving deltas: 100% (22/22), done.

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
import torch    
import cv2
import numpy as np
import matplotlib.pyplot as plt
import requests
import torchvision.transforms as transforms
from PIL import Image
import io

# %%
# %cd /kaggle/working/YOLO-V8-CAM
# Out:
# /kaggle/working/YOLO-V8-CAM

# %%
# !pip install ttach
# Out:
# Collecting ttach
#   Downloading ttach-0.0.3-py3-none-any.whl.metadata (5.2 kB)
# Downloading ttach-0.0.3-py3-none-any.whl (9.8 kB)
# Installing collected packages: ttach
# Successfully installed ttach-0.0.3

# %%
from yolo_cam.eigen_cam import EigenCAM
from yolo_cam.utils.image import show_cam_on_image, scale_cam_image

# %%
img = cv2.imread('/kaggle/working/eye-diseases-1/test/images/CSCR10_jpg.rf.06873b8e38c6e5ffa506b6d955cfce89.jpg')
img = cv2.resize(img, (640, 640))
rgb_img = img.copy()
img = np.float32(img) / 255

# %%
os.listdir('/kaggle/working')
# Out:
# ['.virtual_documents',
#  'eye-diseases-1',
#  'yolo11n.pt',
#  'runs',
#  'YOLO-V8-CAM',
#  'yolov8s.pt']

# %%
import ultralytics
from ultralytics import YOLO
model = YOLO('/kaggle/working/yolov8s.pt') 
model.cpu()
# Out:
# YOLO(
#   (model): DetectionModel(
#     (model): Sequential(
#       (0): Conv(
#         (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (1): Conv(
#         (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (2): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(96, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(32, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (3): Conv(
#         (conv): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (4): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(128, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (5): Conv(
#         (conv): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (6): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0-1): 2 x Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (7): Conv(
#         (conv): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (8): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(512, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (9): SPPF(
#         (cv1): Conv(
#           (conv): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): MaxPool2d(kernel_size=5, stride=1, padding=2, dilation=1, ceil_mode=False)
#       )
#       (10): Upsample(scale_factor=2.0, mode='nearest')
#       (11): Concat()
#       (12): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (13): Upsample(scale_factor=2.0, mode='nearest')
#       (14): Concat()
#       (15): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(192, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (16): Conv(
#         (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (17): Concat()
#       (18): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(384, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (19): Conv(
#         (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#         (act): SiLU(inplace=True)
#       )
#       (20): Concat()
#       (21): C2f(
#         (cv1): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (cv2): Conv(
#           (conv): Conv2d(768, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn): BatchNorm2d(512, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#           (act): SiLU(inplace=True)
#         )
#         (m): ModuleList(
#           (0): Bottleneck(
#             (cv1): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (cv2): Conv(
#               (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(256, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#           )
#         )
#       )
#       (22): Detect(
#         (cv2): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(64, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (cv3): ModuleList(
#           (0): Sequential(
#             (0): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (1): Sequential(
#             (0): Conv(
#               (conv): Conv2d(256, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#           (2): Sequential(
#             (0): Conv(
#               (conv): Conv2d(512, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (1): Conv(
#               (conv): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#               (bn): BatchNorm2d(128, eps=0.001, momentum=0.03, affine=True, track_running_stats=True)
#               (act): SiLU(inplace=True)
#             )
#             (2): Conv2d(128, 80, kernel_size=(1, 1), stride=(1, 1))
#           )
#         )
#         (dfl): DFL(
#           (conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         )
#       )
#     )
#   )
# )

# %%
os.listdir('/kaggle/working/runs/detect')
# Out:
# ['train', 'predict']

# %%
target_layers =[model.model.model[-2]]

# %%
cam = EigenCAM(model, target_layers,task='od')

# %%
cam = EigenCAM(model, target_layers,task='od')
grayscale_cam = cam(rgb_img)[0, :, :]
cam_image = show_cam_on_image(img, grayscale_cam, use_rgb=True)
plt.imshow(cam_image)
plt.show()
# Out:
# 0: 640x640 (no detections), 375.1ms
# Speed: 3.1ms preprocess, 375.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
grayscale_cam = cam(rgb_img)[0, :, :]
cam_image = show_cam_on_image(img, grayscale_cam, use_rgb=True)
plt.imshow(cam_image)
plt.show()
# Out:
# 0: 640x640 (no detections), 373.4ms
# Speed: 7.5ms preprocess, 373.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)

# %%
target_layers =[model.model.model[-2], model.model.model[-3], model.model.model[-4]]

# %%
cam = EigenCAM(model, target_layers,task='od')
grayscale_cam = cam(rgb_img)[0, :, :]
cam_image = show_cam_on_image(img, grayscale_cam, use_rgb=True)
plt.imshow(cam_image)
plt.show()
# Out:
# 0: 640x640 1 Central Serous Chorioretinopathy, 17.9ms
# Speed: 2.8ms preprocess, 17.9ms inference, 124.8ms postprocess per image at shape (1, 3, 640, 640)

# %%
im = cv2.cvtColor(rgb_img, cv2.COLOR_RGB2BGR)
Image.fromarray(np.hstack((im, cam_image)))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x640>

# %%
# Out:
# 0: 640x640 (no detections), 16.2ms
# Speed: 8.1ms preprocess, 16.2ms inference, 26.4ms postprocess per image at shape (1, 3, 640, 640)

# %% [markdown]
# train yolov9

# %%
import pandas as pd
from tabulate import tabulate

# Manually input the data into a dictionary
data = {
    'Model': ['YOLOv8', 'YOLOv9'],  
    'Accuracy': [53.57, 54.24],          
    'Precision': [52.24, 52.02],          
    'Recall': [62.10, 60.56],             
    'F1 score': [56.23, 55.6]            
}

# Convert the dictionary into a DataFrame
comparison_df = pd.DataFrame(data)

# Save the table as a CSV file
comparison_df.to_csv('/kaggle/working/manual_model_comparison.csv', index=False)

# Print the table in a grid format
print("Model Comparison Table:")
print(tabulate(comparison_df, headers='keys', tablefmt='grid'))

# Find the model with the highest accuracy
best_model_row = comparison_df.loc[comparison_df['Accuracy'].idxmax()]
best_model = best_model_row['Model']
best_accuracy = best_model_row['Accuracy']

print(f"\nThe model with the highest accuracy is {best_model} with an accuracy of {best_accuracy:.2f}%.")
# Out:
# Model Comparison Table:
# +----+---------+------------+-------------+----------+------------+
# |    | Model   |   Accuracy |   Precision |   Recall |   F1 score |
# +====+=========+============+=============+==========+============+
# |  0 | YOLOv8  |      53.57 |       52.24 |    62.1  |      56.23 |
# +----+---------+------------+-------------+----------+------------+
# |  1 | YOLOv9  |      54.24 |       52.02 |    60.56 |      55.6  |
# +----+---------+------------+-------------+----------+------------+
#
# The model with the highest accuracy is YOLOv9 with an accuracy of 54.24%.

# %%
# !yolo task=detect mode=train model=yolov9s.pt data=/kaggle/working/eye-diseases-1/data.yaml epochs=100 imgsz=640 batch=32 lr0=0.005 momentum=0.95 weight_decay=0.001 cos_lr=True plots=True
